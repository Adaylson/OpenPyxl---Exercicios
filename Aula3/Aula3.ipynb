# %% [markdown]
# # Acessando dados de uma planilha

# %%
from openpyxl import load_workbook

wb = load_workbook('Só alegria temp.xlsx')

ws = wb['Segunda planilha']
# Out:
# 'Segunda planilha'

# %%
for linha in ws.values:
    print(linha)
    for valor in linha:
        print(valor)
# Out:
# ('TESTE', None, 4, 5, 6, 7, 8, 9, 10)
# TESTE
# None
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# (None, 1000, 5, 6, 7, 8, 9, 10, 11)
# None
# 1000
# 5
# 6
# 7
# 8
# 9
# 10
# 11
# (None, None, 6, 7, 8, 9, 10, 11, 12)
# None
# None
# 6
# 7
# 8
# 9
# 10
# 11
# 12
# (None, None, 7, 8, 9, 10, 11, 12, 13)
# None
# None
# 7
# 8
# 9
# 10
# 11
# 12
# 13
# (None, None, 8, 9, 10, 11, 12, 13, 14)
# None
# None
# 8
# 9
# 10
# 11
# 12
# 13
# 14
# (None, None, 9, 10, 11, 12, 13, 14, 15)
# None
# None
# 9
# 10
# 11
# 12
# 13
# 14
# 15
# (None, None, 10, 11, 12, 13, 14, 15, 16)
# None
# None
# 10
# 11
# 12
# 13
# 14
# 15
# 16
# (None, None, 11, 12, 13, 14, 15, 16, 17)
# None
# None
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# (None, None, 12, 13, 14, 15, 16, 17, 18)
# None
# None
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# (None, None, 13, 14, 15, 16, 17, 18, 19)
# None
# None
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# (None, None, 14, 15, 16, 17, 18, 19, 20)
# None
# None
# 14
# 15
# 16
# 17
# 18
# 19
# 20
# ...

# %%
for row in ws.iter_rows(min_row=1,max_col=9,max_row=10, values_only=True):
    print(row)
# Out:
# ('TESTE', None, 4, 5, 6, 7, 8, 9, 10)
# (None, 1000, 5, 6, 7, 8, 9, 10, 11)
# (None, None, 6, 7, 8, 9, 10, 11, 12)
# (None, None, 7, 8, 9, 10, 11, 12, 13)
# (None, None, 8, 9, 10, 11, 12, 13, 14)
# (None, None, 9, 10, 11, 12, 13, 14, 15)
# (None, None, 10, 11, 12, 13, 14, 15, 16)
# (None, None, 11, 12, 13, 14, 15, 16, 17)
# (None, None, 12, 13, 14, 15, 16, 17, 18)
# (None, None, 13, 14, 15, 16, 17, 18, 19)
